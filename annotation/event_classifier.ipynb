# %%
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate
# from common.models.place import Event
from langchain_core.language_models.chat_models import BaseChatModel
from loguru import logger
import json
from pydantic import BaseModel
from collections import Counter
from typing import Tuple, Dict, List
from langchain_ollama import ChatOllama
import os
from dotenv import load_dotenv
from pydantic import BaseModel, Field, ConfigDict

# %%
load_dotenv()

model = ChatOllama(
	base_url=os.environ.get("OLLAMA_HOST"),
	model="llama3.1:8b",
	num_gpu=-1,
	validate_model_on_init=True,
	temperature=0.3
)

# %%
class Response(BaseModel):
	'''Model output for a single-option classification task.'''

	model_config = ConfigDict(str_strip_whitespace=True, extra="forbid")
	
	thinking: str = Field(
		...,
		description=(
			"Brief justification explaining why the selected option best matches "
			"the input text. This field is for interpretability only."
		),
		examples=[
			"The text sets up the hero's normal life and environment before any conflict occurs.",
			"The antagonist performs harmful acts that create obstacles for the hero.",
			"The hero is forced out of a safe place due to circumstances beyond their control.",
			"There is a direct confrontation involving physical combat."
		],
		min_length=1 # No permite strings vacíos
	)

	response: int = Field(
		...,
		description=(
			"Zero-based index of the selected option from the provided list. "
			"The value must correspond to exactly one available option."
		),
		examples=[0, 2, 5],
		ge=0  # mayor o igual que 0
		)

# %%
system_prompt = SystemMessagePromptTemplate.from_template(template="""You are an expert narrative analysis assistant. Your task is to classify a text fragment by selecting the most specific narrative event from a closed list of options.

Instructions:
- Select exactly ONE option from the list.
- Each option is identified by its index number (0, 1, 2, ...).
- Return ONLY the index number as an integer in "response".
- Do NOT invent options or return natural language in "response".
- If multiple options are applicable, select the one that is the most detailed and specific.
- Abstract or general options should only be chosen if no specific option applies.
Available options:
\"\"\"{options}\"\"\"

{previous_thought}
Output format:
{{
  "thinking": "Brief justification based on the text",
  "response": int
}}
""")

human_prompt = HumanMessagePromptTemplate.from_template(
	"""Text to classify:
\"\"\"{event}\"\"\""""
)

event_prompt = ChatPromptTemplate.from_messages([
	system_prompt,
	human_prompt,
])

# %%
def build_options_prompt(
	node: Dict,
	self_name: str = None
) -> str:
	options = []
	
	for child_id, info in node.get("children", {}).items():
		options.append((child_id, info["description"]))

	if self_name:
		options.append((self_name, node["description"]))

	lines = [
		f"{idx}. {node_id}: {description}" 
		for idx, (node_id, description) in enumerate(options)
	]

	return "\n".join(lines), options

def build_options_prompt_by_list(
	options: list
) -> str:
	lines = [
		f"{idx}. {node_id}: {description}" 
		for idx, (node_id, description) in enumerate(options)
	]
	return "\n".join(lines)

# %%
with open("data/event_with_descriptions.json", "r") as f:
	taxonomy_tree = json.load(f)

# %%
options_prompt = []
for node, info in taxonomy_tree["children"].items():
	options_prompt.append(f"- {node}: {info['description']}")
options_str = "\n".join(options_prompt)

# %%
print(options_str)
# Out:
# - move: Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.
# - resolution: Closure of the story with conflict resolution, hero's victory, recognition, punishment of the villain, transformations, and symbolic closure such as weddings or thrones.

# %%
options_prompt = []
for node, info in taxonomy_tree["children"]["move"]["children"].items():
	options_prompt.append(f"- {node}: {info['description']}")
options_str = "\n".join(options_prompt)

# %%
print(options_str)
# Out:
# - setup: Initial context and situation of the hero, showing their state, environment, and relationships before any conflict.
# - conflict: Problems and obstacles faced by the hero, including interdictions, lacks, struggles, marks received, connective incidents, and villain advantages.
# - preparation: Planning and acquiring resources to face challenges, including temporary absence, violation of interdictions, obtaining objects and allies, guidance from mentors, strategies, and contact with the enemy.
# - beginning_of_counteraction: Start of the hero's active response to conflicts and obstacles.
# - helper_move: Intervention of allies or external forces to support the hero, including obtaining objects, resolving lacks, and rescues.
# - false_hero_make_unfounded_claim: Appearance of a false hero who claims undeserved credit.
# - attempt_at_reconnaissance: Attempts to explore or gather information about the enemy to plan action.

# %%
options,options_list =build_options_prompt(taxonomy_tree)

# %%
options
# Out:
# "0. move: Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.\n1. resolution: Closure of the story with conflict resolution, hero's victory, recognition, punishment of the villain, transformations, and symbolic closure such as weddings or thrones."

# %%
def extract_event(model: BaseChatModel, folktale_event: str, options:str, previous_thought:str = "" ):
	event_chain = event_prompt | model.with_structured_output(Response)
	response = event_chain.invoke({
		"options": options,
		"event": folktale_event,
		"previous_thought": previous_thought
	})
	return response.response, response.thinking

# %% [markdown]
# ---

# %%
texto= "The suitor swore before the court that he would marry the princess and bind his fate to the royal family. He allowed the wedding to be proclaimed and accepted the gifts and honors of a future husband. Yet in secret he intended to flee the kingdom once he had secured the dowry, having never meant to fulfill the promised marriage."
id,t=extract_event(model,texto,options)

# %%
options_list[id]
# Out:
# ('move',
#  'Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.')

# %%
def hierarchical_event_classification_with_desc(
	model: BaseChatModel,
	folktale_event: str,
	taxonomy_tree: Dict,
	n_rounds: int = 3,
	verbose: bool = False
) -> Tuple[str, str]:
	"""
	Clasifica un evento usando una taxonomía jerárquica con descripciones.

	Args:
		model: Instancia de BaseChatModel.
		folktale_event: Texto del evento a clasificar.
		taxonomy_tree: Diccionario de taxonomía con estructura {node: {"description": ..., "children": {...}}}.
		n_rounds: Número de veces a preguntar al LLM por cada nivel.

	Returns:
		Tuple[str, str]: (evento final elegido, justificación final)
	"""

	current_nodes = taxonomy_tree["children"]
	previous_event = None
	final_thinking = []
	options_str,options_list = build_options_prompt(taxonomy_tree)
	level = 0

	if verbose:
		print("=== Inicio de clasificación jerárquica ===")
		print(f"Evento a clasificar: {folktale_event}")

	while current_nodes:
		votes = []
		thoughts = []
		final_thinking_str = "Previous decision or reasoning to consider:\n" + "\n".join(final_thinking)

		if verbose:
			print(f"\n--- Nivel {level} ---")
			print("Opciones disponibles:")
			print(options_str)

		# Preguntar al LLM n_rounds veces
		for i in range(n_rounds):
			event, thinking = extract_event(
				model=model,
				folktale_event=folktale_event,
				options=options_str,
				previous_thought=final_thinking_str
			)
			votes.append(event)
			thoughts.append(thinking)

			if verbose:
				print(f"\nLlamada al modelo ({i + 1}/{n_rounds})")
				print(f"  Evento propuesto: {options_list[event]}")
				print(f"  Justificación: {thinking}")

		if verbose: print("\n---\n")

		# Voto por mayoría
		vote_count = Counter(votes)
		max_freq = max(vote_count.values())
		most_frequent = [v for v, c in vote_count.items() if c == max_freq]

		winning_event = most_frequent[0]
		# winning_event, _ = vote_count.most_common(1)[0]

		if len(most_frequent)>1:
			selected = [options_list[i] for i in most_frequent]
			selected_str = build_options_prompt_by_list(selected)
			event, thinking = extract_event(
				model=model,
				folktale_event=folktale_event,
				options=selected_str,
				previous_thought=final_thinking_str
			)
			winning_event = most_frequent[event]

			if verbose:
				print(f" Empate:")
				print(selected_str)
				print(f"  Evento propuesto: {selected[event]}")
				print(f"  Justificación: {thinking}")

		final_thinking.extend(
			thoughts[i] for i, v in enumerate(votes) if v == winning_event
		)
		
		winning_event = options_list[winning_event][0]

		if verbose:print(f"  Evento propuesto: {winning_event}")

		# Si el evento se repite o no tiene hijos
		if winning_event == previous_event:
			if verbose:
				print("Evento repetido. Finalizando clasificación.")
			return winning_event, final_thinking

		if not current_nodes[winning_event]["children"]:
			if verbose:
				print("El evento ganador no tiene hijos. Finalizando clasificación.")
			return winning_event, final_thinking
		

		options_str,options_list = build_options_prompt(current_nodes[winning_event],winning_event)

		current_nodes = current_nodes[winning_event]["children"]
		previous_event = winning_event

		if verbose:print(f"Descendiendo a los hijos de: {winning_event}")
		level+=1

	if verbose:
		print("\n=== Fin de clasificación ===")
		print(f"  Evento propuesto: {previous_event}")
		print(f"  Justificación: {final_thinking}")

	return previous_event, final_thinking

# %%
texto = "The suitor publicly pledged to marry the princess, participated in the wedding preparations, and accepted all gifts and honors of a future husband. However, he secretly planned to abandon the kingdom immediately after receiving the dowry, having never intended to honor the marriage contract. His actions constitute a deliberate deception regarding matrimony, aimed at personal gain while misleading the royal family and the princess."
final_event, final_thinking = hierarchical_event_classification_with_desc(
	model=model,
	folktale_event=texto,
	taxonomy_tree=taxonomy_tree,
	n_rounds=5,
	verbose = True
)

# print("Evento final:", final_event)
# print("Justificación:", final_thinking)
# Out:
# === Inicio de clasificación jerárquica ===
# Evento a clasificar: The suitor publicly pledged to marry the princess, participated in the wedding preparations, and accepted all gifts and honors of a future husband. However, he secretly planned to abandon the kingdom immediately after receiving the dowry, having never intended to honor the marriage contract. His actions constitute a deliberate deception regarding matrimony, aimed at personal gain while misleading the royal family and the princess.
#
# --- Nivel 0 ---
# Opciones disponibles:
# 0. move: Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.
# 1. resolution: Closure of the story with conflict resolution, hero's victory, recognition, punishment of the villain, transformations, and symbolic closure such as weddings or thrones.
#
# Llamada al modelo (1/5)
#   Evento propuesto: ('move', 'Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (2/5)
#   Evento propuesto: ('move', 'Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (3/5)
#   Evento propuesto: ('move', 'Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.')
#   Justificación: The text describes a specific event where a suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (4/5)
#   Evento propuesto: ('move', 'Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (5/5)
#   Evento propuesto: ('move', 'Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# ---
#
#   Evento propuesto: move
# Descendiendo a los hijos de: move
#
# --- Nivel 1 ---
# Opciones disponibles:
# 0. setup: Initial context and situation of the hero, showing their state, environment, and relationships before any conflict.
# 1. conflict: Problems and obstacles faced by the hero, including interdictions, lacks, struggles, marks received, connective incidents, and villain advantages.
# 2. preparation: Planning and acquiring resources to face challenges, including temporary absence, violation of interdictions, obtaining objects and allies, guidance from mentors, strategies, and contact with the enemy.
# 3. beginning_of_counteraction: Start of the hero's active response to conflicts and obstacles.
# 4. helper_move: Intervention of allies or external forces to support the hero, including obtaining objects, resolving lacks, and rescues.
# 5. false_hero_make_unfounded_claim: Appearance of a false hero who claims undeserved credit.
# 6. attempt_at_reconnaissance: Attempts to explore or gather information about the enemy to plan action.
# 7. move: Main action of the story, including setup, conflict, preparation, counteractions, and external help that drives the narrative.
#
# Llamada al modelo (1/5)
#   Evento propuesto: ('conflict', 'Problems and obstacles faced by the hero, including interdictions, lacks, struggles, marks received, connective incidents, and villain advantages.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain, which is a clear example of conflict.
#
# Llamada al modelo (2/5)
#   Evento propuesto: ('conflict', 'Problems and obstacles faced by the hero, including interdictions, lacks, struggles, marks received, connective incidents, and villain advantages.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (3/5)
#   Evento propuesto: ('conflict', 'Problems and obstacles faced by the hero, including interdictions, lacks, struggles, marks received, connective incidents, and villain advantages.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (4/5)
#   Evento propuesto: ('conflict', 'Problems and obstacles faced by the hero, including interdictions, lacks, struggles, marks received, connective incidents, and villain advantages.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (5/5)
#   Evento propuesto: ('conflict', 'Problems and obstacles faced by the hero, including interdictions, lacks, struggles, marks received, connective incidents, and villain advantages.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# ---
#
#   Evento propuesto: conflict
# Descendiendo a los hijos de: conflict
#
# --- Nivel 2 ---
# Opciones disponibles:
# 0. hero_interdiction: Obstacles that prevent the hero from acting freely, including villainy, false marriages, expulsions, kidnappings, and murders.
# 1. lack: Deficiencies that motivate the hero's action, including absence of a partner or material resources.
# 2. hero_departure: Moment when the hero leaves their initial environment to face challenges.
# 3. struggle: Physical or moral conflicts of the hero, including direct confrontations with antagonists or their agents.
# 4. branding: Marks or physical signs the hero receives during conflict, either permanent or temporary injuries.
# 5. connective_incident: Events that connect and advance the narrative, such as requests for help or decisions to depart.
# 6. villain_gains_information: Moments when the antagonist gains an advantage through information, increasing difficulty for the hero.
# 7. conflict: Problems and obstacles faced by the hero, including interdictions, lacks, struggles, marks received, connective incidents, and villain advantages.
#
# Llamada al modelo (1/5)
#   Evento propuesto: ('hero_interdiction', 'Obstacles that prevent the hero from acting freely, including villainy, false marriages, expulsions, kidnappings, and murders.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain, which is a clear example of villainy.
#
# Llamada al modelo (2/5)
#   Evento propuesto: ('hero_interdiction', 'Obstacles that prevent the hero from acting freely, including villainy, false marriages, expulsions, kidnappings, and murders.')
#   Justificación: The suitor's actions are a clear example of villainy, as he deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (3/5)
#   Evento propuesto: ('hero_interdiction', 'Obstacles that prevent the hero from acting freely, including villainy, false marriages, expulsions, kidnappings, and murders.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (4/5)
#   Evento propuesto: ('hero_interdiction', 'Obstacles that prevent the hero from acting freely, including villainy, false marriages, expulsions, kidnappings, and murders.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (5/5)
#   Evento propuesto: ('hero_interdiction', 'Obstacles that prevent the hero from acting freely, including villainy, false marriages, expulsions, kidnappings, and murders.')
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain, which is a clear example of villainy.
#
# ---
#
#   Evento propuesto: hero_interdiction
# Descendiendo a los hijos de: hero_interdiction
#
# --- Nivel 3 ---
# Opciones disponibles:
# 0. villainy: Malicious acts by the antagonist that hinder the hero's action.
# 1. false_matrimony: Deceptions related to marriages or false promises that complicate the hero's situation.
# 2. expulsion: Expulsion of the hero from a safe environment, forcing their departure.
# 3. kidnapping: Kidnapping that separates the hero or important characters from their environment.
# 4. murder: Murder that aggravates the conflict and generates greater obstacles.
# 5. hero_interdiction: Obstacles that prevent the hero from acting freely, including villainy, false marriages, expulsions, kidnappings, and murders.
#
# Llamada al modelo (1/5)
#   Evento propuesto: ('false_matrimony', "Deceptions related to marriages or false promises that complicate the hero's situation.")
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain, which is a clear example of false_matrimony.
#
# Llamada al modelo (2/5)
#   Evento propuesto: ('false_matrimony', "Deceptions related to marriages or false promises that complicate the hero's situation.")
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain, which is a clear example of false_matrimony.
#
# Llamada al modelo (3/5)
#   Evento propuesto: ('false_matrimony', "Deceptions related to marriages or false promises that complicate the hero's situation.")
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain.
#
# Llamada al modelo (4/5)
#   Evento propuesto: ('false_matrimony', "Deceptions related to marriages or false promises that complicate the hero's situation.")
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain, which is a clear example of false_matrimony.
#
# Llamada al modelo (5/5)
#   Evento propuesto: ('false_matrimony', "Deceptions related to marriages or false promises that complicate the hero's situation.")
#   Justificación: The text describes a specific event where the suitor deceives the royal family and the princess by pretending to marry the princess for personal gain, which is a clear example of false_matrimony.
#
# ---
#
#   Evento propuesto: false_matrimony
# El evento ganador no tiene hijos. Finalizando clasificación.

# %%
file= "data/event_test.json"

with open(file, "r", encoding="utf-8") as f:
	event_data = json.load(f)
for sample in event_data["samples"]:

	event, thinking = hierarchical_event_classification_with_desc(
		model=model,
		folktale_event=sample["text"],
		taxonomy_tree=taxonomy_tree,
		n_rounds=5,
		verbose = False
	)
	print("ID:", sample["id"])
	print("Type:", sample["type"])
	print("Text:", sample["text"])
	print("---")
	print("Thinking:", thinking)
	print("Response:", event)
	print("---")
	# if sample["type"] != event:
	# 	print("ID:", sample["id"])
	# 	print("Type:", sample["type"])
	# 	print("Text:", sample["text"])
	# 	print("---")
	# 	print("Thinking:", thinking)
	# 	print("Response:", event)
	# 	print("---")
# Out:
# ID: D
# Type: initial_situation
# Text: She lived quietly by the river, respected by her neighbors and unaware that her peaceful routine was about to end.
# ---
# Thinking: ["The text describes a setup for an impending change in the protagonist's life, which is likely to be the main action of the story.", "The passage sets up a situation where the protagonist's life is about to change, indicating the beginning of a conflict or event.", "The text describes a setup for an impending change in the protagonist's life, introducing a contrast between her current peaceful state and the upcoming disruption.", "The narrative event described in this fragment is setting up a potential conflict or change in the protagonist's life, which suggests it's not yet a resolution. The focus on the protagonist's 'peaceful routine' being disrupted implies an action (move) is about to occur.", "The given fragment sets up a scene where the protagonist's life is about to change, introducing conflict or tension. This is a key element in setting up the main action of the story.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption.", "The passage sets up a situation where the protagonist's life is about to change, introducing a contrast between her current peaceful state and the upcoming disruption."]
# Response: setup
# ---
# ID: E
# Type: hero_interdiction
# Text: The king issued a decree forbidding anyone to leave the city, trapping the hero inside as danger closed in.
# ---
# Thinking: ['The given text describes the setup and conflict of the story, where the hero is trapped due to external circumstances.', 'The narrative event described is the setup of conflict and preparation for external help, which drives the story forward.', 'This fragment describes a turning point where the hero is trapped and danger approaches, which drives the narrative forward.', 'The given text describes the setup and conflict of the story, where the hero is trapped due to external circumstances. This event sets the stage for further actions and events.', 'This fragment describes a pivotal moment in the story where the hero is confined and threatened by external forces. The main action of the story is unfolding with this setup.', 'This fragment describes the setup and conflict of the story, where the hero is trapped due to external circumstances. This event sets the stage for further actions and events.', 'This event describes the setup and conflict of the story, where the hero is trapped due to external circumstances. This fragment describes a turning point where the hero is trapped and danger approaches, which drives the narrative forward.', 'This fragment describes the setup and conflict of the story, where the hero is trapped due to external circumstances. This event sets the stage for further actions and events.', 'This event describes the setup and conflict of the story, where the hero is trapped due to external circumstances.', 'This event describes the setup of conflict and preparation for external help, where the hero is trapped due to external circumstances.', 'This fragment describes a turning point where the hero is trapped and danger approaches, which drives the narrative forward.', 'This fragment describes a turning point where the hero is trapped and danger approaches, which drives the narrative forward.', 'This fragment describes a turning point where the hero is trapped and danger approaches, which drives the narrative forward.', 'This fragment describes a turning point where the hero is trapped and danger approaches, which drives the narrative forward.', 'This fragment describes a turning point where the hero is trapped and danger approaches, which drives the narrative forward.']
# Response: initial_situation
# ---
# ID: F
# Type: lack_of_money
# Text: Without wealth or allies, he realized he could not protect what mattered most to him.
# ---
# Thinking: ["The protagonist is facing a problem and recognizing their limitations, which sets up a potential conflict. This is more specific than the general 'move' option.", 'The protagonist is aware of his inability to safeguard something precious due to lack of resources and support.', 'The protagonist recognizes his inability to safeguard something precious due to lack of resources and support.', 'The protagonist is aware of their inability to safeguard something important due to lack of resources and support.', 'The protagonist is facing a difficult situation where they feel vulnerable and unable to safeguard their loved ones or important possessions.', 'The protagonist recognizes their inability to safeguard something important due to lack of resources and support.', 'The protagonist recognizes their inability to safeguard something important due to lack of resources and support.', 'The protagonist is aware of their inability to safeguard something important due to lack of resources and support.', 'The protagonist recognizes their inability to safeguard something precious due to lack of resources and support.', 'The protagonist is aware of their inability to safeguard something important due to lack of resources and support.', 'The protagonist recognizes their inability to safeguard something important due to lack of resources and support.', 'The protagonist is aware of their inability to safeguard something important due to lack of resources and support.', 'The protagonist is aware of their inability to safeguard something important due to lack of resources and support.', 'The protagonist is aware of their inability to safeguard something important due to lack of resources and support.', 'The protagonist is aware of their inability to safeguard something important due to lack of resources and support.', 'The protagonist recognizes their inability to safeguard something important due to lack of resources and support.', 'The protagonist is aware of their inability to safeguard something important due to lack of resources and support.', 'The protagonist recognizes their inability to safeguard something important due to lack of resources and support.', 'The protagonist recognizes their inability to safeguard something important due to lack of resources and support.', 'The protagonist recognizes their inability to safeguard something important due to lack of resources and support.']
# Response: lack_of_money
# ---
# ID: G
# Type: hero_departure
# Text: At dawn, she packed her belongings and crossed the border, knowing she could never return unchanged.
# ---
# Thinking: ["The narrative event described involves a character taking action (packing and crossing the border) which sets up a potential conflict or change for the protagonist. This is more specific than 'move' as it describes a key moment in the story.", 'The narrative event described is a pivotal moment in the story where the protagonist takes action, leaving behind her old life. This is a key point of transformation for the character.', "The narrative event described is a pivotal moment in the story where the protagonist takes action (crossing the border) that sets the stage for change. This is more specific than 'move' as it involves a deliberate action with consequences.", "The text describes a character's action of crossing a border, which is a significant event in the narrative. This event has consequences for the character, implying that it will have an impact on their life.", "The narrative event described involves a character taking action (packing and crossing the border) which is likely a pivotal moment in the story. This event sets up conflict or tension, as indicated by the character's knowledge that she can't return 'unchanged'.", 'The narrative event described involves a character taking action (packing and crossing the border) which sets up a potential conflict or change for the protagonist.', "The narrative event described involves a character taking action (packing and crossing the border) which sets up a potential conflict or change for the protagonist. This is more specific than 'move' as it describes a key moment in the story.", "The narrative event described involves a character taking action (packing and crossing the border) which sets up a potential conflict or change for the protagonist. This is more specific than 'move' as it describes a key moment in the story.", "The narrative event described involves a character taking action (packing and crossing the border) which sets up a potential conflict or change for the protagonist. This is more specific than 'move' as it describes a key moment in the story.", 'The narrative event described involves a character taking action (packing and crossing the border) which sets up a potential conflict or change for the protagonist.']
# Response: beginning_of_counteraction
# ---
# ID: H
# Type: fight
# Text: Steel clashed in the courtyard as the hero finally faced the general who had destroyed his family.
# ---
# Thinking: ['The passage describes a pivotal moment of conflict between the hero and the villain, setting up a confrontation that will drive the narrative forward.', 'The text describes a confrontation between the hero and the villain, which is a key moment of conflict in the story.', 'The text describes a confrontation between the hero and the villain, setting up a conflict that will drive the narrative forward.', 'The description of a physical confrontation between two characters suggests that this event is part of the main action of the story, which drives the narrative.', 'The text describes a confrontation between the hero and the general, which is a key moment of conflict in the story.', 'The text describes a physical confrontation between two characters, which is a key moment of conflict in the story.', 'The passage describes a physical confrontation between two characters, which is a key moment of conflict in the story. This event drives the narrative forward and sets up a pivotal moment of conflict.', 'The passage describes a physical confrontation between two characters, which is a key moment of conflict in the story.', 'The description of a physical confrontation between two characters suggests that this event is part of the conflict, which is a key moment in the story.', 'The passage describes a physical confrontation between two characters, which is a key moment of conflict in the story and drives the narrative forward.', 'The passage describes a physical confrontation between two characters, which is a key moment of conflict in the story and drives the narrative forward.', 'The passage describes a physical confrontation between two characters, which is a key moment of conflict in the story and drives the narrative forward.', 'The passage describes a physical confrontation between two characters, which is a key moment of conflict in the story.', 'The passage describes a physical confrontation between two characters, which is a key moment of conflict in the story.', 'The passage describes a physical confrontation between two characters, which is a key moment of conflict in the story.', 'The passage describes a physical confrontation between two characters, specifically the hero and the general, which is a key moment of conflict in the story.', 'The passage describes a physical confrontation between two characters, specifically the hero and the general, which is a key moment of conflict in the story.', 'The passage describes a physical confrontation between two characters, specifically the hero and the general, which is a key moment of conflict in the story.', 'The passage describes a physical confrontation between two characters, specifically the hero and the general, which is a key moment of conflict in the story.', "The description of 'steel clashing' suggests a physical confrontation, and the context implies that this is a direct confrontation between the hero and the antagonist (the general)."]
# Response: fight
# ---
# ID: I
# Type: receive_injury
# Text: A deep scar remained on his arm, a permanent reminder of the price he paid to survive.
# ---
# Thinking: ["The text describes a consequence of a past event (surviving) and its impact on the character's physical appearance.", "The text describes a consequence of an event in the story, specifically a physical injury. This is most closely related to 'move' as it sets up the conflict and drives the narrative forward.", 'The text describes a consequence of an event in the story, specifically a physical harm suffered by the protagonist.', "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", 'The text describes a consequence of an event that occurred in the past, specifically a physical injury. This is a specific example of conflict resolution.', "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", 'The text describes a consequence of an event in the story, specifically a physical harm suffered by the protagonist.', 'The text describes a consequence of an event in the story, specifically a physical harm suffered by the protagonist.', 'The text describes a consequence of an event in the story, specifically a physical harm suffered by the protagonist.', "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a consequence of an event in the story, specifically a physical injury that serves as a reminder of the protagonist's past experience.", "The text describes a physical injury that serves as a reminder of the protagonist's past experience."]
# Response: branding
# ---
# ID: J
# Type: call_for_help
# Text: Desperate and outnumbered, she sent a message asking for help from those who still trusted her.
# ---
# Thinking: ['The protagonist is in a state of desperation and needs external aid, which suggests that the narrative is building up towards a critical moment or conflict.', 'The protagonist is in a vulnerable position, sending a message for external aid, which indicates a turning point or setup for the main action.', 'The protagonist is in a difficult situation and is seeking assistance, which indicates the story has reached a point of conflict or preparation for counteractions.', 'The given text describes a moment of desperation and a plea for external assistance, which is part of the setup and conflict preparation in the narrative.', 'The protagonist is in a difficult situation and is seeking external aid, which suggests that the narrative is building up to a key moment or conflict.', 'The protagonist is in a state of desperation and needs external aid, indicating that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative is building up towards a critical moment or conflict.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative is building up towards a critical moment or conflict.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, indicating that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, indicating that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative has reached a point of conflict or preparation for counteractions.', 'The protagonist is in a state of desperation and needs external aid, which suggests that the narrative has reached a point of conflict or preparation for counteractions.']
# Response: call_for_help
# ---
# ID: K
# Type: departure_decision
# Text: After long reflection, he chose to accept his fate and pursue the enemy beyond the mountains.
# ---
# Thinking: ["The protagonist is making a decision to move forward with the story's conflict, which drives the narrative.", 'The protagonist is making a decision that drives the narrative forward, setting up a potential conflict or action.', 'The protagonist is making a decision that will drive the narrative forward, setting up conflict or preparation for future events.', "The protagonist is making a decision that drives the narrative forward, which implies it's a key moment in the story.", 'The protagonist is making a decision to take action against the enemy, which implies conflict and setup for further events.', 'The protagonist is making a decision that drives the narrative forward, setting up conflict or preparation for future events.', 'The protagonist is making a decision that drives the narrative forward, setting up conflict or preparation for future events.', 'The protagonist is making a decision that drives the narrative forward, setting up conflict or preparation for future events.', 'The protagonist is making a decision that drives the narrative forward, setting up conflict or preparation for future events.', 'The protagonist is making a decision that drives the narrative forward, setting up conflict or preparation for future events.']
# Response: beginning_of_counteraction
# ---
# ID: L
# Type: villain_gains_information
# Text: Hidden among servants, the villain overheard plans that would later give him the upper hand.
# ---
# Thinking: ["The given text describes a plot point where the villain gains an advantage by overhearing important information. This is a specific event in the story's setup or conflict preparation.", 'The provided text describes a specific event where the villain gains an advantage by overhearing secret information. This is a key moment in the story setup and foreshadows future conflict.', 'This event describes a plot twist where the villain gains an advantage through eavesdropping, which is a specific and detailed action.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage. This is not a general resolution of the story, but rather a key plot development.', 'The given text describes a specific event in the story where the villain gains an advantage by overhearing important information. This is a key moment in the narrative that sets up future events.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage. This is not a general resolution of the story, but rather a key plot development.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.', 'The narrative event described is a specific action taken by the villain, which sets up future conflict and gives him an advantage.']
# Response: villain_gains_information
# ---
# ID: M
# Type: absentation
# Text: She trained in isolation for months, far from home, preparing herself for the trial ahead.
# ---
# Thinking: ["The text describes a character's preparation and setup before a critical event (the trial), which is a key aspect of the narrative.", "The passage describes a character's preparation and setup for an upcoming event (the trial), which is a key part of the narrative.", "The text describes a character's preparation and setup before a significant event (the trial), which is an essential part of the narrative.", "The narrative event described is the protagonist's preparation and setup before a significant event (the trial), which suggests it is part of the 'move' category.", "The text describes a protagonist's preparation and setup before a significant event (the trial), which is a key element of the main action.", "The passage describes a character's preparation and setup before a significant event (the trial), which is an essential part of the narrative.", "The passage describes a character's preparation and setup before a significant event (the trial), which is an essential part of the narrative.", "The passage describes a character's preparation and setup before a critical event (the trial), which is a key aspect of the narrative.", "The passage describes a character's preparation and setup before a critical event (the trial), which is a key aspect of the narrative.", "The passage describes a character's preparation and setup before a significant event (the trial), which is an essential part of the narrative.", "The passage describes a character's preparation and setup before a significant event (the trial), which is an essential part of the narrative. This involves temporary separation from the environment to prepare the action.", "The passage describes a character's preparation and setup before a significant event (the trial), which is an essential part of the narrative.", "The passage describes a character's preparation and setup before a significant event (the trial), which is an essential part of the narrative. The character is described as training in isolation for months, indicating temporary separation from her environment.", 'The protagonist is engaging in preparation and setup before a significant event (the trial), which involves temporary separation from her environment.', "The passage describes a character's preparation and setup before a significant event (the trial), which is an essential part of the narrative. The specific action described is temporary separation from her environment to prepare for the action."]
# Response: absentation
# ---
# ID: N
# Type: breaking_interdiction
# Text: Ignoring the warning carved into the gate, he entered the forbidden ruins anyway.
# ---
# Thinking: ['The protagonist is taking a risk by entering the forbidden ruins despite a warning, which suggests a move towards conflict or setup.', 'The protagonist is taking an action that sets up potential conflict or danger, which is a key element of the narrative.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', "The narrative event described is the protagonist's decision to enter a forbidden place despite a warning, which sets up conflict and drives the story forward.", 'The protagonist is taking an action that sets up a potential conflict or consequence, which is a key element of the main action in the story.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.', 'The protagonist is taking a deliberate action that goes against a clear warning, indicating a setup for potential conflict or consequences.']
# Response: setup
# ---
# ID: O
# Type: get_present
# Text: An old traveler gifted her a compass said to always point toward truth.
# ---
# Thinking: ['The given text fragment is about an event that occurs in the story, where the protagonist receives a gift from another character. This gift has special properties that will likely impact the narrative.', 'The event described is related to the setup or preparation of the story, as it introduces an important plot device (the compass) and sets the tone for the narrative.', "The given text describes an event where the protagonist receives a gift from another character, which sets up a potential journey or quest for truth. This is a specific narrative event that fits under 'move'.", 'The given text fragment describes an event where a character receives a gift from another character, which is a specific action that drives the narrative forward.', 'The narrative event described is related to an object being given or received, which implies a specific action and setup for the story.', 'The event described is related to an object being given or received, which implies a specific action and setup for the story.', 'The event described is related to an object being given or received, which implies a specific action and setup for the story.', 'The event described is related to an object being given or received, which implies a specific action and setup for the story.', 'The event described is related to an object being given or received, which implies a specific action and setup for the story.']
# Response: move
# ---
# ID: P
# Type: guidance
# Text: The mentor explained the cost of failure and showed him the path no one else dared to walk.
# ---
# Thinking: ["This event shows a turning point in the story where the protagonist is presented with a difficult decision, which aligns with the 'preparation' aspect of option 0. move.", 'This event is a turning point in the story where the protagonist is presented with a difficult choice, which sets up the conflict that will drive the narrative forward.', "This text fragment describes a pivotal moment in the story where the protagonist is presented with a choice or a challenge, which sets the stage for potential conflict. The mentor's explanation and demonstration serve as a catalyst for the protagonist's decision-making process.", 'This text describes a pivotal moment in the story where the protagonist is being prepared for an important challenge or decision, which aligns with option 0. move.', 'The narrative event described is a moment where guidance and warning are given to the protagonist, indicating a turning point or a critical decision in their journey.', 'This event shows guidance from a mentor, which is a specific aspect of preparation.', "This event shows a turning point in the story where the protagonist is presented with a difficult decision, which aligns with the 'preparation' aspect of option 2. preparation.", 'This event shows guidance from a mentor, which is a key aspect of preparation.', 'This event is a moment where guidance and warning are given to the protagonist, indicating a turning point or a critical decision in their journey.', 'This event is a moment where guidance and warning are given to the protagonist, indicating a turning point or a critical decision in their journey.', 'This event shows guidance from a mentor, which is a key aspect of preparation.', 'This event shows guidance from a mentor, which is a specific aspect of preparation.', 'This event shows guidance from a mentor, which is a key aspect of preparation.', 'This event shows guidance from a mentor, which is a key aspect of preparation.', 'This event shows guidance from a mentor, which is a specific aspect of preparation.']
# Response: guidance
# ---
# ID: Q
# Type: make_contact_with_enemy
# Text: Disguised as a merchant, she spoke directly with her enemy for the first time.
# ---
# Thinking: ['The event described is a confrontation between the protagonist and her adversary, which sets up the potential for conflict or resolution. This specific action of speaking directly with an enemy suggests a pivotal moment in their relationship.', 'The event described is a key moment of confrontation and setup for potential conflict resolution. It involves direct interaction between two characters with an established adversarial relationship.', 'The given text describes a specific event where the protagonist interacts with their adversary in a non-standard manner (disguise), which is a key moment leading up to potential conflict or resolution.', 'The given text describes a specific scene where the protagonist interacts with their adversary in disguise. This is a key moment of confrontation and tension, which drives the narrative forward.', 'The text describes a specific encounter between two characters, where one is disguised and interacting with their adversary.', 'The protagonist interacts with their adversary in disguise, which is a key moment of confrontation and tension.', 'The protagonist interacts with their adversary in disguise, which is a key moment of confrontation and tension.', 'The protagonist interacts with their adversary in disguise, which is a key moment of confrontation and tension.', 'The protagonist interacts with their adversary in disguise, which is a key moment of confrontation and tension.']
# Response: move
# ---
# ID: R
# Type: trickery
# Text: Rather than attack directly, he spread false rumors to weaken the opposing forces.
# ---
# Thinking: ['The protagonist is using a strategic approach to gain an advantage over his opponent, rather than engaging in direct combat.', 'The given text describes a specific action taken by a character in the story, which is to spread false rumors. This action is part of the setup and preparation for the main conflict.', 'The narrative event described is a strategic action taken by a character to gain an advantage in conflict. This action involves a specific counteraction (spreading false rumors) rather than direct confrontation.', "The narrative event described is a strategic action taken by one of the characters, which falls under 'move' as it sets up the conflict and drives the story forward.", "The narrative event described is a strategic action taken by the character to gain an advantage in conflict, which falls under 'move'.", "The protagonist is using a strategic approach to gain an advantage over his opponent by spreading false rumors, which falls under 'move' as it sets up the conflict and drives the story forward.", "The protagonist is using a strategic approach to gain an advantage over his opponent by spreading false rumors, which falls under 'move' as it sets up the conflict and drives the story forward.", "The protagonist is using a strategic approach to gain an advantage over his opponent by spreading false rumors, which falls under 'move' as it sets up the conflict and drives the story forward.", "The protagonist is using a strategic approach to gain an advantage over his opponent by spreading false rumors, which falls under 'move' as it sets up the conflict and drives the story forward.", "The protagonist is using a strategic approach to gain an advantage over his opponent by spreading false rumors, which falls under 'move' as it sets up the conflict and drives the story forward."]
# Response: move
# ---
# ID: S
# Type: beginning_of_counteraction
# Text: From that moment on, the hero no longer reacted to events but actively challenged them.
# ---
# Thinking: ["The given text describes a shift in the hero's behavior from passivity to proactivity, which is a key moment in the narrative where the conflict escalates and the story takes a new turn.", "The text describes a shift in the hero's behavior from reacting to events to proactively challenging them, which is a key aspect of conflict preparation and counteractions.", "The text describes a shift in the hero's behavior from reacting to events to proactively challenging them, which indicates a change in the narrative direction and conflict escalation.", "The text describes a shift in the hero's behavior from reacting to proactively challenging events. This indicates a change in the narrative dynamics and suggests that the story is moving towards a more active phase.", "The given text describes a shift in the hero's behavior from reacting passively to events to proactively challenging them. This change represents a turning point or a significant development in the story.", "The text describes a shift in the hero's behavior from reacting passively to events to proactively challenging them. This change represents a turning point or a significant development in the story.", "The given text describes a shift in the hero's behavior from reacting to events to proactively challenging them, which indicates a change in the narrative direction and conflict escalation.", "The text describes a shift in the hero's behavior from reacting passively to events to proactively challenging them. This change represents a turning point or a significant development in the story.", "The given text describes a shift in the hero's behavior from reacting passively to events to proactively challenging them. This change represents a turning point or a significant development in the story.", "The given text describes a shift in the hero's behavior from reacting to proactively challenging events. This indicates a change in the narrative dynamics and suggests that the story is moving towards a more active phase."]
# Response: beginning_of_counteraction
# ---
# ID: T
# Type: receipt_object
# Text: A mysterious ally intervened, placing a powerful artifact in her hands at the crucial moment.
# ---
# Thinking: ['The narrative event described involves an external help that drives the plot forward, specifically the introduction of a powerful artifact.', 'The text describes an external event that drives the narrative forward, specifically the introduction of a powerful artifact.', 'The text describes an action that drives the narrative forward and introduces a turning point in the story.', "The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward. This is more specific than 'resolution' as it's not yet clear how this will resolve the conflict.", 'The text describes an external event that drives the narrative forward, specifically a counteraction by a mysterious ally.', "The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward. This is more specific than 'resolution' as it's not yet clear how this will resolve the conflict.", 'The introduction of the powerful artifact is an external event that drives the narrative forward and introduces a turning point in the story.', "The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward. This is more specific than 'resolution' as it's not yet clear how this will resolve the conflict.", "The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward. This is more specific than 'resolution' as it's not yet clear how this will resolve the conflict.", 'The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward.', 'The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward.', 'The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward.', 'The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward.', 'The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward.', 'The narrative event described involves an external action (the intervention of a mysterious ally) and a plot development (placement of a powerful artifact), which drives the story forward.']
# Response: helper_move
# ---
# ID: U
# Type: release_from_captivity
# Text: The prisoners were freed, and the fear that once controlled them dissolved instantly.
# ---
# Thinking: ["This fragment describes a moment of closure for the story's conflict, as the prisoners are finally set free. This directly relates to the resolution of the narrative.", "The narrative event described is the resolution of a conflict (the prisoners' freedom) and the transformation of their emotional state.", 'This sentence describes a moment of conflict resolution, where the prisoners are finally liberated from their captivity.', 'The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', 'The text describes a moment of resolution where the conflict (fear) is resolved for the prisoners.', 'This sentence describes a moment of conflict resolution, where the prisoners are finally liberated from their captivity. The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', 'The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', "This fragment describes a moment of closure for the story's conflict, as the prisoners are finally set free. This directly relates to the resolution of the narrative.", 'The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', 'This sentence describes a moment of conflict resolution, where the prisoners are finally liberated from their captivity. The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', 'This sentence describes a moment of conflict resolution, where the prisoners are finally liberated from their captivity. The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', 'This sentence describes a moment of conflict resolution, where the prisoners are finally liberated from their captivity. The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', 'This sentence describes a moment of conflict resolution, where the prisoners are finally liberated from their captivity. The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', 'This sentence describes a moment of conflict resolution, where the prisoners are finally liberated from their captivity. The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).', 'This sentence describes a moment of conflict resolution, where the prisoners are finally liberated from their captivity. The narrative event described is the resolution of a conflict (the fear controlling the prisoners) which led to a positive outcome (their freedom).']
# Response: solution_difficult_task
# ---
# ID: V
# Type: pursuit_and_rescue
# Text: Riding through the night, he chased the kidnappers until the captives were finally safe.
# ---
# Thinking: ["The narrative event described is a specific action that drives the plot forward (chasing the kidnappers), which suggests it's part of the main action.", "The narrative fragment describes a specific action of pursuit and rescue, which is a key part of the story's conflict resolution.", "The given text describes a specific action of pursuit and rescue, which is a key part of the story's conflict.", 'The narrative fragment describes a high-stakes action sequence where the protagonist actively pursues and confronts the antagonists, ultimately leading to the resolution of the conflict.', 'The narrative event described involves a chase and rescue of captives, which is a specific action that drives the plot forward.', "The narrative event described is a specific action that drives the plot forward (chasing the kidnappers), which suggests it's part of the main action.", "The narrative event described is a specific action that drives the plot forward (chasing the kidnappers), which suggests it's part of the main action.", 'The narrative fragment describes a high-stakes action sequence where the protagonist actively pursues and confronts the antagonists, ultimately leading to the resolution of the conflict.', "The narrative event described is a specific action that drives the plot forward (chasing the kidnappers), which suggests it's part of the main action.", "The narrative event described is a specific action that drives the plot forward (chasing the kidnappers), which suggests it's part of the main action. The text describes a high-stakes action sequence where the protagonist actively pursues and confronts the antagonists, ultimately leading to the resolution of the conflict."]
# Response: move
# ---
# ID: W
# Type: false_hero_make_unfounded_claim
# Text: Another warrior stepped forward, falsely claiming credit for deeds he had never performed.
# ---
# Thinking: ['The event described is a specific action within the story, where one character accuses another of misdeeds. This is not a general resolution or closure, but rather an incident that drives the narrative.', 'The narrative event described is a counteraction or conflict escalation, where an imposter claims false credit. This is not the main action of the story (move) nor the closure (resolution).', "The event described is a specific action that occurs within the narrative, involving deception and false claims. This is most closely related to 'counteractions', which involves actions taken by characters in response to or as a reaction to other events.", 'The event described is a specific action taken by a character in the story, which is likely part of the main conflict or setup.', 'The event described involves a character taking action (stepping forward) and making a false claim, which is a specific instance of conflict or counteraction in the narrative.', "The event described is a specific action taken by a character in the story, which involves deception and false claims. This is most closely related to 'counteractions', but it's more specific as it describes an imposter claiming false credit.", 'The event described is a specific action within the story where one character accuses another of misdeeds. This is not a general resolution or closure, but rather an incident that drives the narrative.', 'The event described is a specific action taken by a character in the story, which is likely part of the main conflict or setup. The character makes a false claim, which escalates the conflict.', "The event described is a specific action taken by a character in the story, which involves deception and false claims. This is most closely related to 'counteractions', but it's more specific as it involves a character making a false claim.", "The event described is a specific action taken by a character in the story, which involves deception and false claims. This is most closely related to 'counteractions', but since it's an imposter making false claims, it's more specifically a conflict escalation."]
# Response: beginning_of_counteraction
# ---
# ID: X
# Type: attempt_at_reconnaissance
# Text: She secretly explored the enemy’s camp, mapping defenses and escape routes.
# ---
# Thinking: ["The given text describes a specific action taken by the protagonist (she), which is to explore the enemy's camp. This action involves gathering information about defenses and escape routes, indicating that it is part of the setup or preparation phase of the story.", "The text describes a specific action taken by the protagonist (she), which is to explore the enemy's camp. This action involves gathering information about defenses and escape routes, indicating that it is part of the setup or preparation for a larger conflict.", "The given text describes a specific action taken by the protagonist (secretly exploring the enemy's camp), which is part of the setup or preparation phase of the story.", "The given text describes a specific action of exploration and mapping, which is part of the main story's setup or preparation phase.", "The given text describes a specific action of the protagonist (secretly exploring the enemy's camp) which is crucial for the plot development. This event sets up the conflict and provides necessary information for further actions.", 'The given text describes a specific action taken by the protagonist (she), which is part of the setup or preparation phase of the story.', "The given text describes a specific action taken by the protagonist (she), which is to explore the enemy's camp. This action involves gathering information about defenses and escape routes, indicating that it is part of the setup or preparation phase of the story.", "The given text describes a specific action taken by the protagonist (she), which is to explore the enemy's camp. This action involves gathering information about defenses and escape routes, indicating that it is part of the setup or preparation phase of the story.", "The given text describes a specific action taken by the protagonist (she), which is to explore the enemy's camp. This action involves gathering information about defenses and escape routes, indicating that it is part of the setup or preparation phase of the story.", "The given text describes a specific action taken by the protagonist (she), which is to explore the enemy's camp. This action involves gathering information about defenses and escape routes, indicating that it is part of the setup or preparation phase of the story."]
# Response: attempt_at_reconnaissance
# ---
# ID: Y
# Type: villain_defeated
# Text: With the final blow, the tyrant fell, and his reign ended forever.
# ---
# Thinking: ['The text describes a decisive moment in the story where the main antagonist is defeated, marking the end of their rule. This event drives the narrative towards its conclusion.', 'The text describes a decisive moment in the story where the main antagonist is defeated, leading to the end of their rule. This event marks a significant turning point in the narrative.', 'The text describes a decisive moment in the story where the main antagonist is defeated, marking the end of their rule. This event drives the narrative towards its conclusion.', 'The text describes a decisive moment in the story where the villain is defeated, leading to the end of their rule. This event marks a turning point in the narrative.', 'The text describes a decisive moment in the story where the main antagonist is defeated, leading to the end of their rule.', 'The text describes a decisive moment in the story where the main antagonist is defeated, marking the end of their rule. This event drives the narrative towards its conclusion.', 'The text describes a decisive moment in the story where the main antagonist is defeated, marking the end of their rule.', 'The text describes a decisive moment in the story where the main antagonist is defeated, leading to the end of their rule.', 'The text describes a decisive moment in the story where the main antagonist is defeated, leading to the end of their rule.', 'The text describes a decisive moment in the story where the main antagonist is defeated, marking the end of their rule.']
# Response: beginning_of_counteraction
# ---
# ID: Z
# Type: unrecognised_arrival
# Text: When he returned home, no one recognized the quiet figure standing at the gate.
# ---
# Thinking: ["The event described is the setup or introduction of a character's change, which is likely part of the main action of the story.", 'The event described is a moment of setup and conflict preparation, where the protagonist returns home but is not recognized by others. This suggests that something has changed about him since his departure.', "The given snippet describes a character's return home and their anonymity, which implies that something has changed about them or their situation. This is likely a consequence of previous events in the story.", 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', "The narrative event described in this fragment is related to a character's return and their lack of recognition by others, which suggests that it is part of the setup or preparation for the main action.", 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The narrative event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The narrative event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.', 'The event described is a moment of setup and conflict preparation in the story, where the protagonist returns home but is not recognized by others.']
# Response: setup
# ---
# ID: AA
# Type: solution_difficult_task
# Text: The impossible riddle was solved, proving beyond doubt who the true hero was.
# ---
# Thinking: ["The text describes a moment of conflict resolution and closure, specifically highlighting the solution of an 'impossible riddle' which implies a challenge or problem that has been overcome.", 'The text describes a moment of conflict resolution and recognition of the true hero.', 'The text describes a moment of conflict resolution and recognition of the true hero.', "The text describes a moment of conflict resolution and recognition of the hero's identity.", 'This text fragment describes a moment of conflict resolution and closure in the story, specifically highlighting the solution of an important challenge.', "The text describes a moment of conflict resolution and recognition of the true hero through the solution of an 'impossible riddle'.", "The text describes a moment of conflict resolution and recognition of the true hero through the solution of an 'impossible riddle'.", 'The text describes a moment of conflict resolution and recognition of the true hero.', "The text describes a moment of conflict resolution and closure, specifically highlighting the solution of an 'impossible riddle' which implies a challenge or problem that has been overcome.", 'This text fragment describes a moment of conflict resolution and closure in the story, specifically highlighting the solution of an important challenge.', "The text describes a moment of conflict resolution and recognition of the true hero through the solution of an 'impossible riddle'.", "This sentence describes a moment of conflict resolution and recognition of the true hero through the solution of an 'impossible riddle', which is a specific challenge.", "The text describes a moment of conflict resolution and recognition of the true hero through the solution of an 'impossible riddle'.", "The text describes a moment of conflict resolution and recognition of the true hero through the solution of an 'impossible riddle'.", "The text describes a moment of conflict resolution and recognition of the true hero through the solution of an 'impossible riddle'."]
# Response: solution_difficult_task
# ---
# ID: AB
# Type: exposure_of_villain
# Text: Before the assembled court, the villain’s lies were revealed one by one.
# ---
# Thinking: ["The text describes a moment of revelation and exposure of the villain's deceit, which is a key event in resolving the conflict.", "The text describes a moment of conflict resolution where the villain's lies are exposed, which is a key event leading up to the story's closure.", "The text describes a specific event where the villain's lies are exposed, which is a crucial moment in resolving the conflict. This matches option 1: resolution.", "The text describes a moment of revelation and exposure of the villain's deceit, which is a key event in resolving the conflict.", "The text describes a moment of revelation and exposure of the villain's deceit, which is a key event in resolving the conflict.", "The text describes a moment of revelation and exposure of the villain's deceit, which is a key event in resolving the conflict.", "The text describes a moment of revelation and exposure of the villain's deceit, which is a key event in resolving the conflict.", "The text describes a moment of revelation and exposure of the villain's deceit, which is a key event in resolving the conflict."]
# Response: exposure_of_villain
# ---
# ID: AC
# Type: psychological_transformation
# Text: He stood taller now, not just in body but in spirit, shaped by everything he had endured.
# ---
# Thinking: ["The text describes a character's transformation and growth as a result of their experiences, which is a specific narrative event.", "The passage describes a character's transformation and growth as a result of their experiences, which suggests that the narrative event is focused on the character's development rather than external actions or conflicts.", "The given text describes a character's transformation and growth as a result of their experiences, which is a specific narrative event.", "The passage describes a character's transformation and growth as a result of their experiences, which is a specific aspect of the narrative.", "The text describes a character's transformation and growth after experiencing hardships, which is a specific narrative event.", "The passage focuses on the character's transformation and growth as a result of their experiences, which is a specific narrative event.", "The passage describes a character's transformation and growth as a result of their experiences, which suggests that the narrative event is focused on the character's development rather than external actions or conflicts.", "The passage describes a character's transformation and growth as a result of their experiences, which is a specific narrative event focused on the character's development.", "The passage describes a character's transformation and growth as a result of their experiences, which is a specific narrative event focused on the character's development rather than external actions or conflicts.", "The passage describes a character's transformation and growth as a result of their experiences, which suggests that the narrative event is focused on the character's development rather than external actions or conflicts.", "The passage describes a character's transformation and growth as a result of their experiences, which is a specific narrative event focused on the character's development rather than external actions or conflicts.", "The passage describes a character's transformation and growth as a result of their experiences, which is a specific narrative event focused on the character's development rather than external actions or conflicts.", "The passage describes a character's transformation and growth as a result of their experiences, which is a specific narrative event focused on the character's development.", "The passage describes a character's transformation and growth as a result of their experiences, which is a specific narrative event focused on the character's development rather than external actions or conflicts."]
# Response: initial_situation
# ---
# ID: AD
# Type: get_throne
# Text: Crowned before the people, she assumed her place as the rightful ruler.
# ---
# Thinking: ['The narrative event described is a specific action related to the assumption of power and recognition by the people.', "The narrative event described is a specific action related to the establishment of the protagonist's authority and position.", 'The text describes a specific event where a character is crowned and assumes their role as a ruler, which implies a moment of recognition and transformation.', 'The narrative event described is the coronation of a new ruler, which implies the transfer of power and recognition by the people.', 'The narrative event described is a specific action related to the assumption of power and recognition by the people.', "The narrative event described is a specific action related to the establishment of the protagonist's authority and position, which involves the coronation of a new ruler.", 'The narrative event described is a specific action related to the assumption of power and recognition by the people.', "The narrative event described is a specific action related to the establishment of the protagonist's authority and position, which involves recognition by the people.", 'The narrative event described is the coronation of a new ruler, which implies the transfer of power and recognition by the people.', 'The narrative event described is a specific action related to the assumption of power and recognition by the people.', 'The narrative event described is a specific action related to the assumption of power and recognition by the people.', 'The text describes a specific event where a character is crowned and assumes their role as a ruler, which implies a moment of recognition and transformation.', "The narrative event described is a specific action related to the assumption of power and recognition by the people. The text explicitly mentions 'crowned' which implies coronation."]
# Response: get_throne
# ---
